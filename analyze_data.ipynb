# %%
from pandas import read_csv
import numpy as np
import random
import matplotlib.pyplot as plt

df = read_csv("end_report.csv")
df.head()
# Out:
#     Step  agent_generation  avg_distance_between_agents  avg_knowledge  \
# 0  400.0                 0                          0.0       0.048941
# 1  400.0                 0                          0.0       0.048518
# 2  400.0                 0                          0.0       0.048860
# 3  400.0                 0                          0.0       0.036079
# 4  400.0                 0                          0.0       0.043816
#
#    avgcurrentAgentKnowledge  best_knowledge  constant_population  epsilon  \
# 0              1.771172e-53        0.573262                    0      0.1
# 1              2.734231e-50        0.573262                    0      0.1
# 2              1.073462e-57        0.573262                    0      0.1
# 3              8.819724e-46        0.539550                    0      0.1
# 4              4.974225e-39        0.561797                    0      0.1
#
#    explored_percentage  explored_weigthed_by_initial_knowledge  \
# 0               0.6875                                0.502974
# 1               0.6350                                0.577186
# 2               0.4875                                0.402913
# 3               0.6675                                0.813243
# 4               0.7075                                0.780227
#
#                                    generation_params  harvest  \
# 0  {'seed': 4, 'std': 5, 'number_gaussians': 2, '...     0.02
# 1  {'seed': 4, 'std': 5, 'number_gaussians': 2, '...     0.02
# 2  {'seed': 4, 'std': 5, 'number_gaussians': 2, '...     0.02
# 3  {'seed': 4, 'std': 5, 'number_gaussians': 2, '...     0.02
# 4  {'seed': 4, 'std': 5, 'number_gaussians': 2, '...     0.02
#
#    initial_curiosity  mean_age  mean_prestige  number_agents  \
# 0                0.0    435.95       1.685199             20
# 1                0.0    437.20       2.099446             20
# 2                0.0    438.85       1.764421             20
# 3                0.0    436.05      14.289824             20
# 4                0.0    438.20       6.707741             20
#
#    number_connection  size  steps  total_initial_knowledge
# 0                  2    20    400                20.264237
# 1                  2    20    400                20.264237
# 2                  2    20    400                20.264237
# 3                  2    20    400                20.264237
# 4                  2    20    400                20.264237

# %%
def plot_smt(name):
    curiosities = sorted(df["initial_curiosity"].unique())
    avg_knowledges = [df[df["initial_curiosity"]==c][name].mean() for c in curiosities]
    std_knowledges = [df[df["initial_curiosity"]==c][name].std() for c in curiosities]
    plt.errorbar(curiosities, avg_knowledges, yerr=std_knowledges, fmt='-o')
    plt.xlabel("Initial Curiosity")
    plt.ylabel(name)
    plt.title(name + " vs Initial Curiosity")
    plt.grid()
    plt.show()
plot_smt("avg_knowledge")

# %%
plot_smt("explored_percentage")

# %%
df.keys()
# Out:
# Index(['Step', 'agent_generation', 'avg_distance_between_agents',
#        'avg_knowledge', 'avgcurrentAgentKnowledge', 'best_knowledge',
#        'constant_population', 'epsilon', 'explored_percentage',
#        'explored_weigthed_by_initial_knowledge', 'generation_params',
#        'harvest', 'initial_curiosity', 'mean_age', 'mean_prestige',
#        'number_agents', 'number_connection', 'size', 'steps',
#        'total_initial_knowledge'],
#       dtype='object')

# %%
plot_smt("explored_weigthed_by_initial_knowledge")
